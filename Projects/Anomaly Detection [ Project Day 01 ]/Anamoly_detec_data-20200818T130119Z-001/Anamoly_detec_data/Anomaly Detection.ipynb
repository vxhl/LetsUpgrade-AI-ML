# %%
import os
import sys
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from scipy.io import loadmat
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ## Import Pyod and the methods

# %%
from pyod.models.pca import PCA
from pyod.models.mcd import MCD
from pyod.models.ocsvm import OCSVM
from pyod.models.lof import LOF
from pyod.models.cblof import CBLOF
from pyod.models.knn import KNN
from pyod.models.hbos import HBOS
from pyod.models.abod import ABOD
from pyod.models.iforest import IForest
from pyod.models.feature_bagging import FeatureBagging

# %% [markdown]
# # Import Metrics Package

# %%
from pyod.utils.utility import standardizer
from pyod.utils.utility import precision_n_scores
from sklearn.metrics import roc_auc_score

# %%
mat_file_list=['arrhythmia.mat','cardio.mat','glass.mat','ionosphere.mat','letter.mat','lympho.mat','mnist.mat','musk.mat','optdigits.mat','pendigits.mat','pima.mat','satellite.mat','satimage-2.mat','shuttle.mat','shuttle.mat','vertebral.mat','vowels.mat','wbc.mat']

# %%
mat_file_list
# Out:
# ['arrhythmia.mat',
#  'cardio.mat',
#  'glass.mat',
#  'ionosphere.mat',
#  'letter.mat',
#  'lympho.mat',
#  'mnist.mat',
#  'musk.mat',
#  'optdigits.mat',
#  'pendigits.mat',
#  'pima.mat',
#  'satellite.mat',
#  'satimage-2.mat',
#  'shuttle.mat',
#  'shuttle.mat',
#  'vertebral.mat',
#  'vowels.mat',
#  'wbc.mat']

# %% [markdown]
# # Loading .mat files

# %%
df_columns=['Data','#Sample','#Dimensions','Outlier Perc','PCA','MCD','OCSVM','LOF','CBLOF','KNN','HBOS','ABOD','IFOREST','FEATUREBAGGING']

# %% [markdown]
# # Precision Time and Roc evolution tables creation

# %%
roc_df=pd.DataFrame(columns=df_columns)
prn_df=pd.DataFrame(columns=df_columns)
time_df=pd.DataFrame(columns=df_columns)
print(roc_df,prn_df,time_df)
# Out:
# Empty DataFrame
# Columns: [Data, #Sample, #Dimensions, Outlier Perc, PCA, MCD, OCSVM, LOF, CBLOF, KNN, HBOS, ABOD, IFOREST, FEATUREBAGGING]
# Index: [] Empty DataFrame
# Columns: [Data, #Sample, #Dimensions, Outlier Perc, PCA, MCD, OCSVM, LOF, CBLOF, KNN, HBOS, ABOD, IFOREST, FEATUREBAGGING]
# Index: [] Empty DataFrame
# Columns: [Data, #Sample, #Dimensions, Outlier Perc, PCA, MCD, OCSVM, LOF, CBLOF, KNN, HBOS, ABOD, IFOREST, FEATUREBAGGING]
# Index: []

# %% [markdown]
# # Exploring Mat Files

# %%
from time import time
random_state = np.random.RandomState(42)
for mat_file in mat_file_list:
    print("\n... Processing",mat_file,'.....')
    mat = loadmat(mat_file)
    
    X = mat['X']
    y = mat['y'].ravel()
    
    outliers_fraction = np.count_nonzero(y) / len(y)
    outliers_percentage = round(outliers_fraction * 100, ndigits=4)
    
    roc_list = [mat_file[:-4], X.shape[0], X.shape[1], outliers_percentage]
    prn_list = [mat_file[:-4], X.shape[0], X.shape[1], outliers_percentage]
    time_list = [mat_file[:-4], X.shape[0], X.shape[1], outliers_percentage]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state = random_state)
    
    X_train_norm, X_test_norm = standardizer(X_train, X_test)
    
    classifiers = {'Angle-based Outlier Detector (ABOD)' : ABOD(contamination=outliers_fraction), 
                  'Cluster-based Local Outlier Factor': CBLOF(contamination=outliers_fraction,check_estimator=False ,random_state=random_state),
                  'Feature Bagging': FeatureBagging(contamination=outliers_fraction, random_state=random_state),
                  'Historgram-base Outlier Detection (HBOS)': HBOS(contamination=outliers_fraction),
                  'Isolation Forest' : IForest(contamination=outliers_fraction, random_state=random_state),
                  'K Nearest Neighbors (KNN)': KNN(contamination=outliers_fraction),
                  'Local Outlier Factor (LOF)' : LOF(contamination=outliers_fraction),
                  'Minimum Covariance Determinant (MCD)': MCD(contamination=outliers_fraction, random_state=random_state),
                  'One-class SVM (OCSVM)': OCSVM(contamination=outliers_fraction),
                  'Principal Component Analysis (PCA)': PCA(contamination=outliers_fraction, random_state=random_state)}
    for clf_name, clf in classifiers.items():
        t0 = time()
        clf.fit(X_train_norm)
        test_scores = clf.decision_function(X_test_norm)
        t1 = time()
        duration = round(t1-t0, 4)
        time_list.append(duration)
        
        roc = round(roc_auc_score(y_test, test_scores), 4)
        prn = round(precision_n_scores(y_test, test_scores), 4)
        
        print(f"{clf_name} ROC: {roc}, precision @ rank n: {prn}, execution time: {duration}s' ")
        
        roc_list.append(roc)
        prn_list.append(prn)
        
    temp_df = pd.DataFrame(time_list).transpose()
    temp_df.columns = df_columns
    time_df = pd.concat([time_df, temp_df], axis=0)
    
    temp_df = pd.DataFrame(roc_list).transpose()
    temp_df.columns = df_columns
    roc_df = pd.concat([roc_df, temp_df], axis=0)
    
    temp_df = pd.DataFrame(prn_list).transpose()
    temp_df.columns = df_columns
    prn_df = pd.concat([prn_df, temp_df], axis=0)
# Out:
# ... Processing arrhythmia.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.7687, precision @ rank n: 0.3571, execution time: 0.2833s'
# Cluster-based Local Outlier Factor ROC: 0.7684, precision @ rank n: 0.4643, execution time: 0.2822s'
# Feature Bagging ROC: 0.7799, precision @ rank n: 0.5, execution time: 1.0243s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.8511, precision @ rank n: 0.5714, execution time: 0.1356s'
# Isolation Forest ROC: 0.8527, precision @ rank n: 0.5714, execution time: 0.8602s'
# K Nearest Neighbors (KNN) ROC: 0.782, precision @ rank n: 0.5, execution time: 0.1645s'
# Local Outlier Factor (LOF) ROC: 0.7787, precision @ rank n: 0.4643, execution time: 0.1267s'
# Minimum Covariance Determinant (MCD) ROC: 0.8228, precision @ rank n: 0.4286, execution time: 1.8298s'
# One-class SVM (OCSVM) ROC: 0.7986, precision @ rank n: 0.5, execution time: 0.0788s'
# Principal Component Analysis (PCA) ROC: 0.7997, precision @ rank n: 0.5, execution time: 0.1267s'
#
# ... Processing cardio.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.5763, precision @ rank n: 0.1875, execution time: 0.6752s'
# Cluster-based Local Outlier Factor ROC: 0.8221, precision @ rank n: 0.4844, execution time: 0.3366s'
# Feature Bagging ROC: 0.4879, precision @ rank n: 0.1406, execution time: 1.3642s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.8453, precision @ rank n: 0.4688, execution time: 0.013s'
# Isolation Forest ROC: 0.9414, precision @ rank n: 0.5, execution time: 0.7856s'
# K Nearest Neighbors (KNN) ROC: 0.6959, precision @ rank n: 0.2812, execution time: 0.3007s'
# Local Outlier Factor (LOF) ROC: 0.4715, precision @ rank n: 0.125, execution time: 0.1715s'
# Minimum Covariance Determinant (MCD) ROC: 0.8781, precision @ rank n: 0.3906, execution time: 1.144s'
# One-class SVM (OCSVM) ROC: 0.9507, precision @ rank n: 0.5938, execution time: 0.1586s'
# Principal Component Analysis (PCA) ROC: 0.9638, precision @ rank n: 0.6875, execution time: 0.007s'
#
# ... Processing glass.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.7104, precision @ rank n: 0.25, execution time: 0.0848s'
# Cluster-based Local Outlier Factor ROC: 0.8506, precision @ rank n: 0.25, execution time: 0.0977s'
# Feature Bagging ROC: 0.7043, precision @ rank n: 0.25, execution time: 0.0698s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.6524, precision @ rank n: 0.0, execution time: 0.005s'
# Isolation Forest ROC: 0.7195, precision @ rank n: 0.25, execution time: 0.5917s'
# K Nearest Neighbors (KNN) ROC: 0.7805, precision @ rank n: 0.25, execution time: 0.017s'
# Local Outlier Factor (LOF) ROC: 0.7774, precision @ rank n: 0.25, execution time: 0.005s'
# Minimum Covariance Determinant (MCD) ROC: 0.7165, precision @ rank n: 0.0, execution time: 0.0698s'
# One-class SVM (OCSVM) ROC: 0.6189, precision @ rank n: 0.25, execution time: 0.002s'
# Principal Component Analysis (PCA) ROC: 0.622, precision @ rank n: 0.25, execution time: 0.004s'
#
# ... Processing ionosphere.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.9004, precision @ rank n: 0.8214, execution time: 0.1535s'
# Cluster-based Local Outlier Factor ROC: 0.8952, precision @ rank n: 0.8036, execution time: 0.0958s'
# Feature Bagging ROC: 0.8933, precision @ rank n: 0.75, execution time: 0.1326s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.5195, precision @ rank n: 0.3393, execution time: 0.016s'
# Isolation Forest ROC: 0.8309, precision @ rank n: 0.6607, execution time: 0.6193s'
# K Nearest Neighbors (KNN) ROC: 0.9134, precision @ rank n: 0.8393, execution time: 0.0319s'
# Local Outlier Factor (LOF) ROC: 0.8989, precision @ rank n: 0.75, execution time: 0.015s'
# Minimum Covariance Determinant (MCD) ROC: 0.9399, precision @ rank n: 0.8571, execution time: 0.1472s'
# One-class SVM (OCSVM) ROC: 0.8372, precision @ rank n: 0.7143, execution time: 0.012s'
# Principal Component Analysis (PCA) ROC: 0.7971, precision @ rank n: 0.5893, execution time: 0.006s'
#
# ... Processing letter.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.8465, precision @ rank n: 0.275, execution time: 0.6769s'
# Cluster-based Local Outlier Factor ROC: 0.7423, precision @ rank n: 0.175, execution time: 0.2593s'
# Feature Bagging ROC: 0.866, precision @ rank n: 0.4, execution time: 1.2666s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.5728, precision @ rank n: 0.125, execution time: 0.0249s'
# Isolation Forest ROC: 0.5778, precision @ rank n: 0.05, execution time: 0.8049s'
# K Nearest Neighbors (KNN) ROC: 0.845, precision @ rank n: 0.3, execution time: 0.2767s'
# Local Outlier Factor (LOF) ROC: 0.8409, precision @ rank n: 0.325, execution time: 0.1681s'
# Minimum Covariance Determinant (MCD) ROC: 0.7499, precision @ rank n: 0.075, execution time: 2.497s'
# One-class SVM (OCSVM) ROC: 0.5744, precision @ rank n: 0.1, execution time: 0.1536s'
# Principal Component Analysis (PCA) ROC: 0.48, precision @ rank n: 0.05, execution time: 0.0096s'
#
# ... Processing lympho.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.9382, precision @ rank n: 0.4, execution time: 0.0608s'
# Cluster-based Local Outlier Factor ROC: 0.9709, precision @ rank n: 0.6, execution time: 0.0957s'
# Feature Bagging ROC: 0.9673, precision @ rank n: 0.6, execution time: 0.0638s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.9964, precision @ rank n: 0.8, execution time: 0.009s'
# Isolation Forest ROC: 0.9855, precision @ rank n: 0.6, execution time: 0.5665s'
# K Nearest Neighbors (KNN) ROC: 0.9636, precision @ rank n: 0.6, execution time: 0.013s'
# Local Outlier Factor (LOF) ROC: 0.9636, precision @ rank n: 0.6, execution time: 0.005s'
# Minimum Covariance Determinant (MCD) ROC: 0.9164, precision @ rank n: 0.6, execution time: 0.0798s'
# One-class SVM (OCSVM) ROC: 0.9636, precision @ rank n: 0.6, execution time: 0.004s'
# Principal Component Analysis (PCA) ROC: 0.9818, precision @ rank n: 0.8, execution time: 0.005s'
#
# ... Processing mnist.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.7813, precision @ rank n: 0.3562, execution time: 12.0704s'
# Cluster-based Local Outlier Factor ROC: 0.8447, precision @ rank n: 0.4007, execution time: 1.9825s'
# Feature Bagging ROC: 0.7259, precision @ rank n: 0.3664, execution time: 84.5425s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.5675, precision @ rank n: 0.1199, execution time: 0.0927s'
# Isolation Forest ROC: 0.7801, precision @ rank n: 0.2979, execution time: 3.4508s'
# K Nearest Neighbors (KNN) ROC: 0.8409, precision @ rank n: 0.4144, execution time: 10.1s'
# Local Outlier Factor (LOF) ROC: 0.7085, precision @ rank n: 0.339, execution time: 9.5445s'
# Minimum Covariance Determinant (MCD) ROC: 0.863, precision @ rank n: 0.3973, execution time: 6.1485s'
# One-class SVM (OCSVM) ROC: 0.8417, precision @ rank n: 0.3801, execution time: 7.4421s'
# Principal Component Analysis (PCA) ROC: 0.8396, precision @ rank n: 0.3767, execution time: 0.2433s'
#
# ... Processing musk.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.0809, precision @ rank n: 0.0333, execution time: 3.6722s'
# Cluster-based Local Outlier Factor ROC: 1.0, precision @ rank n: 1.0, execution time: 0.6672s'
# Feature Bagging ROC: 0.5228, precision @ rank n: 0.1667, execution time: 22.3682s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.9999, precision @ rank n: 0.9667, execution time: 0.0958s'
# Isolation Forest ROC: 0.9996, precision @ rank n: 0.9333, execution time: 2.1881s'
# K Nearest Neighbors (KNN) ROC: 0.7348, precision @ rank n: 0.2333, execution time: 3.0958s'
# Local Outlier Factor (LOF) ROC: 0.5323, precision @ rank n: 0.1333, execution time: 2.7875s'
# Minimum Covariance Determinant (MCD) ROC: 1.0, precision @ rank n: 0.9667, execution time: 27.655s'
# One-class SVM (OCSVM) ROC: 1.0, precision @ rank n: 1.0, execution time: 1.9089s'
# Principal Component Analysis (PCA) ROC: 1.0, precision @ rank n: 1.0, execution time: 0.2513s'
#
# ... Processing optdigits.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.4428, precision @ rank n: 0.0161, execution time: 3.8627s'
# Cluster-based Local Outlier Factor ROC: 0.7852, precision @ rank n: 0.0, execution time: 0.8048s'
# Feature Bagging ROC: 0.4641, precision @ rank n: 0.0484, execution time: 21.689s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.8822, precision @ rank n: 0.2581, execution time: 0.0549s'
# Isolation Forest ROC: 0.5764, precision @ rank n: 0.0161, execution time: 1.5459s'
# K Nearest Neighbors (KNN) ROC: 0.3824, precision @ rank n: 0.0, execution time: 2.8613s'
# Local Outlier Factor (LOF) ROC: 0.4584, precision @ rank n: 0.0484, execution time: 2.5073s'
# Minimum Covariance Determinant (MCD) ROC: 0.3486, precision @ rank n: 0.0, execution time: 2.4065s'
# One-class SVM (OCSVM) ROC: 0.4972, precision @ rank n: 0.0, execution time: 2.3118s'
# Principal Component Analysis (PCA) ROC: 0.504, precision @ rank n: 0.0, execution time: 0.0818s'
#
# ... Processing pendigits.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.7008, precision @ rank n: 0.0308, execution time: 2.3398s'
# Cluster-based Local Outlier Factor ROC: 0.9609, precision @ rank n: 0.3077, execution time: 0.4648s'
# Feature Bagging ROC: 0.4687, precision @ rank n: 0.0462, execution time: 7.5069s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.9294, precision @ rank n: 0.2615, execution time: 0.018s'
# Isolation Forest ROC: 0.9422, precision @ rank n: 0.2769, execution time: 1.124s'
# K Nearest Neighbors (KNN) ROC: 0.7602, precision @ rank n: 0.0462, execution time: 1.3135s'
# Local Outlier Factor (LOF) ROC: 0.481, precision @ rank n: 0.0462, execution time: 1.0373s'
# Minimum Covariance Determinant (MCD) ROC: 0.8271, precision @ rank n: 0.0615, execution time: 4.2446s'
# One-class SVM (OCSVM) ROC: 0.93, precision @ rank n: 0.2923, execution time: 1.5179s'
# Principal Component Analysis (PCA) ROC: 0.9332, precision @ rank n: 0.3385, execution time: 0.014s'
#
# ... Processing pima.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.6757, precision @ rank n: 0.5106, execution time: 0.2334s'
# Cluster-based Local Outlier Factor ROC: 0.684, precision @ rank n: 0.4681, execution time: 0.1236s'
# Feature Bagging ROC: 0.6446, precision @ rank n: 0.4468, execution time: 0.1536s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.7169, precision @ rank n: 0.5213, execution time: 0.005s'
# Isolation Forest ROC: 0.6604, precision @ rank n: 0.4787, execution time: 0.5416s'
# K Nearest Neighbors (KNN) ROC: 0.7252, precision @ rank n: 0.5106, execution time: 0.0529s'
# Local Outlier Factor (LOF) ROC: 0.6604, precision @ rank n: 0.4787, execution time: 0.016s'
# Minimum Covariance Determinant (MCD) ROC: 0.7047, precision @ rank n: 0.4787, execution time: 0.0768s'
# One-class SVM (OCSVM) ROC: 0.6423, precision @ rank n: 0.4574, execution time: 0.016s'
# Principal Component Analysis (PCA) ROC: 0.6639, precision @ rank n: 0.5, execution time: 0.0031s'
#
# ... Processing satellite.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.5681, precision @ rank n: 0.3918, execution time: 3.0339s'
# Cluster-based Local Outlier Factor ROC: 0.7234, precision @ rank n: 0.5574, execution time: 0.6223s'
# Feature Bagging ROC: 0.557, precision @ rank n: 0.4051, execution time: 12.2103s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.7393, precision @ rank n: 0.5466, execution time: 0.0299s'
# Isolation Forest ROC: 0.6843, precision @ rank n: 0.5719, execution time: 1.3733s'
# K Nearest Neighbors (KNN) ROC: 0.6781, precision @ rank n: 0.4994, execution time: 1.9378s'
# Local Outlier Factor (LOF) ROC: 0.5551, precision @ rank n: 0.4051, execution time: 1.7344s'
# Minimum Covariance Determinant (MCD) ROC: 0.792, precision @ rank n: 0.6747, execution time: 4.0831s'
# One-class SVM (OCSVM) ROC: 0.636, precision @ rank n: 0.5224, execution time: 2.1832s'
# Principal Component Analysis (PCA) ROC: 0.5783, precision @ rank n: 0.4559, execution time: 0.0429s'
#
# ... Processing satimage-2.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.86, precision @ rank n: 0.2593, execution time: 2.6449s'
# Cluster-based Local Outlier Factor ROC: 0.9987, precision @ rank n: 0.8889, execution time: 0.5326s'
# Feature Bagging ROC: 0.4971, precision @ rank n: 0.0741, execution time: 9.8726s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.9837, precision @ rank n: 0.5926, execution time: 0.0329s'
# Isolation Forest ROC: 0.9962, precision @ rank n: 0.8889, execution time: 1.1868s'
# K Nearest Neighbors (KNN) ROC: 0.9505, precision @ rank n: 0.3704, execution time: 1.5369s'
# Local Outlier Factor (LOF) ROC: 0.5006, precision @ rank n: 0.0741, execution time: 1.2168s'
# Minimum Covariance Determinant (MCD) ROC: 0.9946, precision @ rank n: 0.5185, execution time: 3.7849s'
# One-class SVM (OCSVM) ROC: 0.9976, precision @ rank n: 0.9259, execution time: 1.7802s'
# Principal Component Analysis (PCA) ROC: 0.9841, precision @ rank n: 0.8519, execution time: 0.0299s'
#
# ... Processing shuttle.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.6186, precision @ rank n: 0.1918, execution time: 27.5593s'
# Cluster-based Local Outlier Factor ROC: 0.6287, precision @ rank n: 0.2336, execution time: 1.9009s'
# Feature Bagging ROC: 0.5211, precision @ rank n: 0.111, execution time: 100.5092s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.9851, precision @ rank n: 0.9857, execution time: 0.0309s'
# Isolation Forest ROC: 0.997, precision @ rank n: 0.9308, execution time: 5.5302s'
# K Nearest Neighbors (KNN) ROC: 0.645, precision @ rank n: 0.2199, execution time: 18.0178s'
# Local Outlier Factor (LOF) ROC: 0.5347, precision @ rank n: 0.1406, execution time: 23.925s'
# Minimum Covariance Determinant (MCD) ROC: 0.9903, precision @ rank n: 0.7534, execution time: 20.3186s'
# One-class SVM (OCSVM) ROC: 0.9922, precision @ rank n: 0.9553, execution time: 83.0489s'
# Principal Component Analysis (PCA) ROC: 0.9902, precision @ rank n: 0.9503, execution time: 0.0599s'
#
# ... Processing shuttle.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.6227, precision @ rank n: 0.1938, execution time: 25.804s'
# Cluster-based Local Outlier Factor ROC: 0.6578, precision @ rank n: 0.2206, execution time: 1.8301s'
# Feature Bagging ROC: 0.5023, precision @ rank n: 0.0669, execution time: 104.0108s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.9868, precision @ rank n: 0.9386, execution time: 0.0319s'
# Isolation Forest ROC: 0.9974, precision @ rank n: 0.9486, execution time: 5.5482s'
# K Nearest Neighbors (KNN) ROC: 0.6549, precision @ rank n: 0.2213, execution time: 17.201s'
# Local Outlier Factor (LOF) ROC: 0.5336, precision @ rank n: 0.155, execution time: 22.5886s'
# Minimum Covariance Determinant (MCD) ROC: 0.9897, precision @ rank n: 0.7477, execution time: 17.8981s'
# One-class SVM (OCSVM) ROC: 0.9923, precision @ rank n: 0.9605, execution time: 83.0828s'
# Principal Component Analysis (PCA) ROC: 0.9907, precision @ rank n: 0.9577, execution time: 0.0618s'
#
# ... Processing vertebral.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.3688, precision @ rank n: 0.0, execution time: 0.0808s'
# Cluster-based Local Outlier Factor ROC: 0.3891, precision @ rank n: 0.0, execution time: 0.0928s'
# Feature Bagging ROC: 0.3688, precision @ rank n: 0.0, execution time: 0.0558s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.3617, precision @ rank n: 0.0, execution time: 0.004s'
# Isolation Forest ROC: 0.3539, precision @ rank n: 0.0, execution time: 0.4737s'
# K Nearest Neighbors (KNN) ROC: 0.3562, precision @ rank n: 0.0, execution time: 0.016s'
# Local Outlier Factor (LOF) ROC: 0.3562, precision @ rank n: 0.0, execution time: 0.004s'
# Minimum Covariance Determinant (MCD) ROC: 0.4203, precision @ rank n: 0.0, execution time: 0.0688s'
# One-class SVM (OCSVM) ROC: 0.4078, precision @ rank n: 0.0, execution time: 0.004s'
# Principal Component Analysis (PCA) ROC: 0.3633, precision @ rank n: 0.0625, execution time: 0.003s'
#
# ... Processing vowels.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.8982, precision @ rank n: 0.2857, execution time: 0.4398s'
# Cluster-based Local Outlier Factor ROC: 0.8608, precision @ rank n: 0.2143, execution time: 0.1695s'
# Feature Bagging ROC: 0.9124, precision @ rank n: 0.2143, execution time: 0.4418s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.7567, precision @ rank n: 0.2143, execution time: 0.007s'
# Isolation Forest ROC: 0.8141, precision @ rank n: 0.1429, execution time: 0.6024s'
# K Nearest Neighbors (KNN) ROC: 0.9746, precision @ rank n: 0.3571, execution time: 0.1197s'
# Local Outlier Factor (LOF) ROC: 0.9192, precision @ rank n: 0.2857, execution time: 0.0509s'
# Minimum Covariance Determinant (MCD) ROC: 0.6966, precision @ rank n: 0.0714, execution time: 1.3185s'
# One-class SVM (OCSVM) ROC: 0.8426, precision @ rank n: 0.2857, execution time: 0.0638s'
# Principal Component Analysis (PCA) ROC: 0.6907, precision @ rank n: 0.2143, execution time: 0.005s'
#
# ... Processing wbc.mat .....
# Angle-based Outlier Detector (ABOD) ROC: 0.9573, precision @ rank n: 0.5556, execution time: 0.1376s'
# Cluster-based Local Outlier Factor ROC: 0.9751, precision @ rank n: 0.6667, execution time: 0.0918s'
# Feature Bagging ROC: 0.979, precision @ rank n: 0.7778, execution time: 0.1187s'
# Historgram-base Outlier Detection (HBOS) ROC: 0.9876, precision @ rank n: 0.6667, execution time: 0.012s'
# Isolation Forest ROC: 0.9674, precision @ rank n: 0.5556, execution time: 0.5107s'
# K Nearest Neighbors (KNN) ROC: 0.9713, precision @ rank n: 0.4444, execution time: 0.0299s'
# Local Outlier Factor (LOF) ROC: 0.979, precision @ rank n: 0.6667, execution time: 0.012s'
# Minimum Covariance Determinant (MCD) ROC: 0.9658, precision @ rank n: 0.5556, execution time: 0.1197s'
# One-class SVM (OCSVM) ROC: 0.9782, precision @ rank n: 0.6667, execution time: 0.008s'
# Principal Component Analysis (PCA) ROC: 0.9775, precision @ rank n: 0.6667, execution time: 0.007s'

# %%
from IPython.core.display import HTML
HTML("""
<style>
    table.dataframe thead th:first-child {
        display: none;
    }
    table.dataframe tbody th {
        display: none;
    }
</style>
""")
# Out:
# <style>
#     table.dataframe thead th:first-child {
#         display: none;
#     }
#     table.dataframe tbody th {
#         display: none;
#     }
# </style>

# %%
roc_df
# Out:
#          Data #Sample #Dimensions Outlier Perc     PCA     MCD   OCSVM  \
# 0  arrhythmia     452         274      14.6018  0
# 0  0.2615  0.2769  0.0462  0.0462  0.0615  0.2923         0.3385
# 0  0.5213  0.4787  0.5106  0.4787  0.4787  0.4574            0.5
# 0  0.5466  0.5719  0.4994  0.4051  0.6747  0.5224         0.4559
# 0  0.5926  0.8889  0.3704  0.0741  0.5185  0.9259         0.8519
# 0  0.9857  0.9308  0.2199  0.1406  0.7534  0.9553         0.9503
# 0  0.9386  0.9486  0.2213   0.155  0.7477  0.9605         0.9577
# 0       0       0       0       0       0       0         0.0625
# 0  0.2143  0.1429  0.3571  0.2857  0.0714  0.2857         0.2143
# 0  0.6667  0.5556  0.4444  0.6667  0.5556  0.6667         0.6667

# %%
time_df
# Out:
#          Data #Sample #Dimensions Outlier Perc      PCA     MCD    OCSVM  \
# 0  arrhythmia     452         274      14.6018   5.2454  3.4714   0.9475
# 0      cardio    1831          21       9.6122   0.6124  0.2932   1.2457
# 0       glass     214           9       4.2056   0.0669  0.0818   0.0668
# 0  ionosphere     351          33      35.8974   0.1267  0.0808   0.1167
# 0      letter    1600          32         6.25   0.5774  0.2533   1.1649
# 0      lympho     148          18       4.0541   0.0588  0.0758   0.0529
# 0       mnist    7603         100       9.2069  12.5255  2.0286  83.0598
# 0        musk    3062         166       3.1679   3.6911  0.6951  22.4519
# 0   optdigits    5216          64       2.8758   3.8866  0.8497     23.2
# 0   pendigits    6870          16       2.2707   2.3308  0.4976   7.5578
# 0        pima     768           8      34.8958   0.2344  0.1306   0.1566
# 0   satellite    6435          36      31.6395    3.004  0.6213  12.3031
# 0  satimage-2    5803          36       1.2235    2.619  0.5266  10.0222
# 0     shuttle   49097           9       7.1511  28.5058  1.8371  101.582
# 0     shuttle   49097           9       7.1511   28.031  1.9198   108.72
# 0   vertebral     240           6         12.5   0.0987  0.0965   0.0652
# 0      vowels    1456          12       3.4341   0.4992  0.1995   0.5056
# 0         wbc     378          30       5.5556   0.1676  0.1027   0.1376
# 0  arrhythmia     452         274      14.6018   0.2833  0.2822   1.0243
# 0      cardio    1831          21       9.6122   0.6752  0.3366   1.3642
# 0       glass     214           9       4.2056   0.0848  0.0977   0.0698
# 0  ionosphere     351          33      35.8974   0.1535  0.0958   0.1326
# 0      letter    1600          32         6.25   0.6769  0.2593   1.2666
# 0      lympho     148          18       4.0541   0.0608  0.0957   0.0638
# 0       mnist    7603         100       9.2069  12.0704  1.9825  84.5425
# 0        musk    3062         166       3.1679   3.6722  0.6672  22.3682
# 0   optdigits    5216          64       2.8758   3.8627  0.8048   21.689
# 0   pendigits    6870          16       2.2707   2.3398  0.4648   7.5069
# 0        pima     768           8      34.8958   0.2334  0.1236   0.1536
# 0   satellite    6435          36      31.6395   3.0339  0.6223  12.2103
# 0  satimage-2    5803          36       1.2235   2.6449  0.5326   9.8726
# 0     shuttle   49097           9       7.1511  27.5593  1.9009  100.509
# 0     shuttle   49097           9       7.1511   25.804  1.8301  104.011
